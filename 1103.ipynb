# %%
from google.colab.patches import cv2_imshow
from google.colab import drive
import numpy as np
import cv2
import matplotlib.pyplot as plt
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = cv2.imread('/content/gdrive/My Drive/di/Images/lena256.jpg')
print(img.shape)
glmg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(glmg)
# Out:
# (256, 256, 3)
# <PIL.Image.Image image mode=L size=256x256>

# %% [markdown]
# 로버츠 검출기

# %%
gx = np.array([[-1, 0], [0,1]], dtype=int)
gx = np.array([[-1, 0], [0,1]], dtype=int)

# %% [markdown]
# 소벨 검출기

# %%
gx = np.array([[-1,0, 0], [-2,0,2], [-1,0,1]], dtype=int)
gx = np.array([[1,2,1], [0,0,0], [-1,-2,-1]], dtype=int)

# %% [markdown]
# 프리윗 검출기

# %%
gx = np.array([[-1,0,0], [-1,0,1], [-1,0,1]], dtype=int)
gx = np.array([[1,1,1], [0,0,0], [-1,-1,-1]], dtype=int)

# %%
gBin = np.zeros(glmg.shape, dtype=int)

threshold = 40

for i in range(glmg.shape[0]):
  for j in range(glmg.shape[1]):
    if outlmg[i, j] > threshold:
      gBin[i,j] = 255

plt.imshow(gBin, cmap='gray')

# %%
outlmg = cv2.Canny(glmg, 200, 250)
plt.imshow(outlmg, cmap='gray')
