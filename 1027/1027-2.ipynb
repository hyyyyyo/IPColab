# %%
from google.colab.patches import cv2_imshow
from google.colab import drive
import numpy as np
import cv2
import matplotlib.pyplot as plt
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = cv2.imread('/content/gdrive/My Drive/di/Images/fcespnoise.bmp')
if img is None:
    print("Error: Image not loaded. Please check the file path.")
else:
    glmg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    cv2_imshow(glmg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
img = cv2.imread('/content/gdrive/My Drive/di/Images/fcespnoise.bmp')
glmg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(glmg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
img = cv2.imread('/content/gdrive/My Drive/di/Images/fcespnoise.bmp')
img = cv2.imread('/content/gdrive/My Drive/di/Images/leneG2.jpg')
glmg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(glmg)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipython-input-4273558032.py in <cell line: 0>()
#       1 img = cv2.imread('/content/gdrive/My Drive/di/Images/fcespnoise.bmp')
#       2 img = cv2.imread('/content/gdrive/My Drive/di/Images/leneG2.jpg')
# ----> 3 glmg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       4 cv2_imshow(glmg)
#
# error: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
